# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
daf = load_diabetes()

# %%
df = pd.DataFrame(daf.data,columns=daf.feature_names)

# %%
daf.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1])

# %%
from sklearn.ensemble import IsolationForest
ifd = IsolationForest(contamination="auto")
predictions = ifd.fit_predict(df)

# %%
import numpy as np
index = np.where(predictions<0)
index
# Out:
# (array([ 10,  15,  23,  26,  29,  32,  35,  43,  58,  72,  76, 114, 117,
#         123, 135, 141, 161, 166, 168, 169, 187, 202, 204, 216, 230, 248,
#         251, 254, 256, 258, 260, 261, 266, 276, 287, 321, 322, 323, 325,
#         336, 346, 349, 350, 352, 353, 354, 366, 376, 379, 394, 405, 406,
#         414, 422, 425, 428, 441]),)

# %%
X = df.values
index = np.where(predictions<0)
plt.scatter(df.iloc[:,4],df.iloc[:,5])
plt.scatter(X[index,4],X[index,5],edgecolors="r")

# %%
plt.scatter(df.iloc[:,4],df.iloc[:,5])

# %%
plt.scatter(X[index,4],X[index,5],edgecolors="r")
